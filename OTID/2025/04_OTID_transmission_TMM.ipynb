# %% [markdown]
# # Transmittance Calculation for Multilayer Structure
#
# This notebook calculates the transmittance of a normal-incident plane wave through a 10-layer structure with alternating materials (ABABABABAB) using the **Transfer Matrix Method (TMM)**.
#
# ## Theoretical Background
#
# The Transfer Matrix Method is a powerful technique for analyzing wave propagation through layered media. For electromagnetic waves at normal incidence:
#
# 1. Each layer is characterized by:
#    - Thickness ($d$)
#    - Refractive index ($n=\sqrt{\epsilon}$ for non-magnetic materials)
#    - Permittivity ($\epsilon$)
#
# 2. The method uses 2×2 matrices to:
#    - Describe wave propagation within each layer (Propagation Matrix, $P$)
#    - Describe boundary conditions at interfaces (Interface Matrix, $T$)
#
# The Propagation Matrix for layer $j$ is given by:
# $$
# P_j = \begin{pmatrix}
# e^{i \delta_j} & 0 \\
# 0 & e^{-i \delta_j}
# \end{pmatrix}
# $$
#  where $\delta_j = \frac{\omega n_j d_j}{c}$ is the optical phase, $\omega$ is the angular frequency, $n_j$ is the refractive index, $d_j$ is the thickness, and $c$ is the speed of light.
#
# The Interface Matrix between layers $j-1$ and $j$ is given by:
# $$
# T_{j-1,j} = \frac{1}{2 n_{j}} \begin{pmatrix}
# n_j + n_{j-1} & n_j - n_{j-1} \\
# n_j - n_{j-1} & n_j + n_{j-1}
# \end{pmatrix}
# $$
# where $n_{j-1}$ is the refractive index of the previous layer (incident), and $n_j$ is the refractive index of the current layer (transmitted).
# $$
#  \begin{pmatrix}
# E^{(+)}_j \\
# E^{(-)}_j
# \end{pmatrix}
# = T_{j-1,j}  \begin{pmatrix}
# E^{(+)}_{j-1} \\
# E^{(-)}_{j-1}
# \end{pmatrix}
# $$
#
#
# 4. The total transfer matrix is the product of all individual matrices:
#    $$ M_{total} = T_N\cdots P_2T_2P_1T_1 $$
#
# 5. Transmittance is calculated from the total matrix elements:
#    $$ T = \left| \frac{1}{M_{22}} \right|^2 \frac{n_{substrate}}{n_{incident}} $$
#
# ## Structure
#
# - 10 layers alternating between Material A ($\epsilon_1$) and Material B ($\epsilon_2$)
# - Pattern: ABABABABAB
# - Incident medium and substrate are air ($n = 1$)
#
# ## Implementation
#
# The following code implements this calculation in Python.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_transmittance(wavelength, thicknesses, epsilon_1, epsilon_2):
    """
    Calculate transmittance through a 10-layer ABABABABAB structure.
    
    Parameters:
    wavelength : float
        Wavelength of incident light (in meters)
    thicknesses : list or array
        Array of 10 layer thicknesses [d1, d2, ..., d10] (in meters)
    epsilon_1 : float
        Permittivity of material A
    epsilon_2 : float
        Permittivity of material B
    
    Returns:
    float : Transmittance (0 to 1)
    """
    
    # Check input validity
    if len(thicknesses) != 10:
        raise ValueError("Exactly 10 layer thicknesses must be provided")
    
    # Constants
    c = 2.99792458e8  # speed of light in m/s
    omega = 2 * np.pi * c / wavelength  # angular frequency
    
    # Refractive indices
    n1 = np.sqrt(epsilon_1)
    n2 = np.sqrt(epsilon_2)
    n0 = 1.0  # air (incident)
    n_sub = 1.0  # air (substrate)
    
    # Layer properties (ABABABABAB)
    ns = [n1, n2] * 5
    
    # Initialize total transfer matrix
    M_total = np.eye(2, dtype=complex)
    
    # Build total transfer matrix
    for i in range(10):
        n_current = ns[i]
        d = thicknesses[i]
        
        # Phase thickness
        delta = omega * n_current * d / c
        
        # Interface matrix
        if i == 0:
            n_prev = n0
        else:
            n_prev = ns[i-1]
            
        T_interface = np.array([
            [(n_current + n_prev), (n_current - n_prev)],
            [(n_current - n_prev), (n_current + n_prev)]
        ]) * 1/(2*n_current)
        
        # Propagation matrix
        P = np.array([
            [np.exp(1j * delta), 0],
            [0, np.exp(-1j * delta)]
        ])
        
        # Update total matrix   P2 T2 P1 T1  
        M_total = P @ T_interface @  M_total 
    
    # Final interface to substrate
    nf = ns[-1] # final layer n 
    T_final = np.array([
        [(n_sub + nf), (n_sub - nf)],
        [(n_sub - nf), (n_sub + nf)]
    ]) * 1 / (2*n_sub)
    
    M_total = T_final @ M_total 
    
    # Transmission coefficient
    t = 1 / M_total[1,1] # python begins with 0
    
    # Transmittance T = np.abs(t)**2 * n_sub / n0
    T = np.abs(t)**2 * n_sub / n0
    
    return T.real

# %% [markdown]
# ## Example Calculation
#
# Let's calculate the transmittance for a specific case:
# - Wavelength: 500 nm
# - Layer thickness: 120 nm each
# - Material A: $\epsilon_1$
# - Material B: $\epsilon_2$

# %%
# Parameters
lambda0 = 500e-9  # 500 nm
d = [120e-9] * 10  # 50 nm each layer
# d = [600e-9, 0, 0, 0, 0, 0, 0, 0, 0, 0] # single layer for test
eps1 = 11.7# 
eps2 = 3.9   # 
# Calculate
T = calculate_transmittance(lambda0, d, eps1, eps2)
print(f'Transmittance: {T:.4f}')
# Out:
# Transmittance: 0.8552

# %% [markdown]
# ## Wavelength Dependence
#
# Let's plot the transmittance as a function of wavelength to see the spectral response.

# %%
# Wavelength sweep
wavelengths = np.linspace(300e-9, 800e-9, 500)  # 300-800 nm
transmittances = [calculate_transmittance(wl, d, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, 'b-')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()

# %%
target_wl = np.linspace(600e-9,700e-9,21)
target_trans = np.zeros(21)
target_trans[8] = 1 
#target_trans[16] = 1

# Plot
plt.figure(figsize=(10, 6))
plt.plot(target_wl * 1e9, target_trans, 'r-o')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()

# %%
#  figure of merit
def fom(thicknesses):
    lw = len(target_wl)
    trans = np.zeros(lw)
    for i in range(lw):
        trans[i] = calculate_transmittance(target_wl[i], thicknesses, eps1, eps2)
    output = np.sum((trans - target_trans)**2)/lw
    return output

# %%
fom(d)
# Out:
# 0.08278081007397525

# %%
from pyswarm import pso #pip install pyswarm

# Define the objective function (example: sum of squares)
# Replace this with your actual function


# Define bounds for the 10 parameters
lb = np.zeros(10)          # Lower bound: 0 for all d_i
ub = np.ones(10) * 300e-9  # Upper bound: 300e-9 for all d_i

# Run PSO optimization
best_position, best_value = pso(
    fom,    # Function to minimize
    lb,                    # Lower bounds
    ub,                    # Upper bounds
    swarmsize=100,          # Number of particles
    maxiter=1000,           # Maximum iterations
    debug=False,             # Print progress
    minstep = 0.5e-9
)

# Print results
print("\nOptimization Results:")
print("Best parameters (d_i):")
for i, d in enumerate(best_position):
    print(f"d_{i+1} = {d:.2e}")
print(f"Minimum value of f: {best_value:.2e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from pyswarm import pso #pip install pyswarm
#       3 # Define the objective function (example: sum of squares)
#       4 # Replace this with your actual function
#       5
#       6
#       7 # Define bounds for the 10 parameters
#       8 lb = np.zeros(10)          # Lower bound: 0 for all d_i
#
# ModuleNotFoundError: No module named 'pyswarm'

# %%
# Wavelength sweep
wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
transmittances = [calculate_transmittance(wl, best_position, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, 'b-')
plt.plot(target_wl * 1e9, target_trans, 'r--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Wavelength sweep
#       2 wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
# ----> 3 transmittances = [calculate_transmittance(wl, best_position, eps1, eps2) for wl in wavelengths]
#       5 # Plot
#       6 plt.figure(figsize=(10, 6))
#
# Cell In[8], line 3, in <listcomp>(.0)
#       1 # Wavelength sweep
#       2 wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
# ----> 3 transmittances = [calculate_transmittance(wl, best_position, eps1, eps2) for wl in wavelengths]
#       5 # Plot
#       6 plt.figure(figsize=(10, 6))
#
# NameError: name 'best_position' is not defined

# %%
from simanneal import Annealer #pip install simanneal 

# Define the objective function (example: sum of squares)


# Define the Simulated Annealing problem
class ParameterOptimization(Annealer):
    def __init__(self, initial_state):
        super(ParameterOptimization, self).__init__(initial_state)
        self.bounds = (0, 300e-9)  # Bounds for d_i

    # Define how to perturb the state (move to a neighbor)
    def move(self):
        # Randomly perturb one parameter
        step_size = 50e-9
        step = step_size * np.random.uniform(-1,1,10) / np.sqrt(10)   # Small random step
        self.state += step
        # Enforce bounds
        self.state = np.clip(self.state, self.bounds[0], self.bounds[1])

    # Define the energy (objective function to minimize)
    def energy(self):
        return fom(self.state)

# Run the optimization
def SA_sim():
    # Initial state: random values between 0 and 300e-9 for 10 parameters
    initial_state = np.random.uniform(0, 300e-9, 10)

    # Set up the annealer
    problem = ParameterOptimization(initial_state)
    problem.Tmax = 25000.0  # Initial temperature
    problem.Tmin = 1      # Final temperature
    problem.steps = 10000   # Number of iterations

    # Run simulated annealing
    best_state, best_energy = problem.anneal()

    # Print results
    print("\nOptimization Results:")
    print("Best parameters (d_i):")
    for i, d in enumerate(best_state):
        print(f"d_{i+1} = {d:.2e}")
    print(f"Minimum value of f: {best_energy:.2e}")

    return best_state, best_energy

best_state, best_energy = SA_sim()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from simanneal import Annealer #pip install simanneal
#       3 # Define the objective function (example: sum of squares)
#       4
#       5
#       6 # Define the Simulated Annealing problem
#       7 class ParameterOptimization(Annealer):
#
# ModuleNotFoundError: No module named 'simanneal'

# %%
# Wavelength sweep
wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
transmittances = [calculate_transmittance(wl, best_state, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, 'b-')
plt.plot(target_wl * 1e9, target_trans, 'r--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Wavelength sweep
#       2 wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
# ----> 3 transmittances = [calculate_transmittance(wl, best_state, eps1, eps2) for wl in wavelengths]
#       5 # Plot
#       6 plt.figure(figsize=(10, 6))
#
# Cell In[10], line 3, in <listcomp>(.0)
#       1 # Wavelength sweep
#       2 wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
# ----> 3 transmittances = [calculate_transmittance(wl, best_state, eps1, eps2) for wl in wavelengths]
#       5 # Plot
#       6 plt.figure(figsize=(10, 6))
#
# NameError: name 'best_state' is not defined

# %%
from scipy.optimize import minimize


# Define bounds for the 10 parameters
bounds = [(0, 300e-9) for _ in range(10)]  # Each d_i between 0 and 300e-9

# Initial guess: random values within bounds
initial_guess = np.random.uniform(0, 300e-9, 10)

# Run optimization

#  Set Optimization Options
# We increase 'maxiter' and set 'disp' to True to see the optimization output.
# 'adaptive=True' can sometimes help Nelder-Mead handle higher dimensions better.
options = {
    'disp': True,          # Print convergence messages
    'xatol': 1e-9,         # Absolute error in xopt between iterations that is acceptable for convergence.
    'fatol': 1e-8,         # Absolute error in func(xopt) between iterations that is acceptable for convergence.
    'adaptive': True,      # Use adaptive parameters proposed by Gao and Han (2012) - may improve performance
    'maxfev': 10000 
}


result = minimize(
    fom,    # Function to minimize
    initial_guess,         # Starting point
    method='Nelder-Mead',       # Use Powell's method
    bounds=bounds,         # Parameter constraints
    options= options   
)
# Extract results
best_params = result.x
best_value = result.fun

# Print results
print("\nOptimization Results:")
print("Best parameters (d_i):")
for i, d in enumerate(best_params):
    print(f"d_{i+1} = {d:.2e}")
print(f"Minimum value of f: {best_value:.2e}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.010078
#          Iterations: 898
#          Function evaluations: 1298
#
# Optimization Results:
# Best parameters (d_i):
# d_1 = 4.69e-08
# d_2 = 8.11e-08
# d_3 = 1.41e-07
# d_4 = 2.45e-07
# d_5 = 9.18e-08
# d_6 = 8.26e-08
# d_7 = 2.35e-07
# d_8 = 2.44e-07
# d_9 = 2.34e-07
# d_10 = 1.28e-10
# Minimum value of f: 1.01e-02

# %%
# Wavelength sweep
wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
transmittances = [calculate_transmittance(wl, best_params, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, 'b-')
plt.plot(target_wl * 1e9, target_trans, 'r--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()

# %%
import numpy as np
import random
from deap import base, creator, tools, algorithms

# Define the objective function
def objective_function(d):
    return fom(d)  # Minimize sum of d_i^2

# Wrapper for DEAP to evaluate individuals
def evaluate(individual):
    d = np.array(individual)
    return (objective_function(d),)  # Return a tuple as required by DEAP

# Custom mutation that respects bounds
def bounded_mutation(individual, mu, sigma, indpb, min_bound, max_bound):
    for i in range(len(individual)):
        if random.random() < indpb:
            individual[i] += random.gauss(mu, sigma)
            individual[i] = max(min_bound, min(max_bound, individual[i]))
    return individual,

# Custom function to enforce bounds after crossover
def enforce_bounds(min_bound, max_bound):
    def decorator(func):
        def wrapper(*args, **kwargs):
            offspring = func(*args, **kwargs)
            for child in offspring:
                for i in range(len(child)):
                    child[i] = max(min_bound, min(max_bound, child[i]))
            return offspring
        return wrapper
    return decorator

# Check if FitnessMin and Individual are already defined to avoid warnings
if not hasattr(creator, 'FitnessMin'):
    creator.create("FitnessMin", base.Fitness, weights=(-1.0,))  # Minimize fitness
if not hasattr(creator, 'Individual'):
    creator.create("Individual", list, fitness=creator.FitnessMin)

# Set up the GA
def setup_ga():
    toolbox = base.Toolbox()
    MIN_BOUND, MAX_BOUND = 0, 300e-9
    toolbox.register("attr_float", random.uniform, MIN_BOUND, MAX_BOUND)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=10)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("evaluate", evaluate)
    toolbox.register("mate", enforce_bounds(MIN_BOUND, MAX_BOUND)(tools.cxBlend), alpha=0.5)
    toolbox.register("mutate", bounded_mutation, mu=0, sigma=50e-9, indpb=0.2, 
                     min_bound=MIN_BOUND, max_bound=MAX_BOUND)
    toolbox.register("select", tools.selTournament, tournsize=3)
    return toolbox, MIN_BOUND, MAX_BOUND

# Main GA function
def GA_sim():
    # Set random seed (optional: uncomment for reproducibility)
    # random.seed(42)
    # np.random.seed(42)
    random.seed()
    np.random.seed()

    # Initialize toolbox
    toolbox, MIN_BOUND, MAX_BOUND = setup_ga()

    # Create population
    population = toolbox.population(n=200)
    
    # Evaluate initial population
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    # Initialize Hall of Fame and seed it with evaluated population
    hof = tools.HallOfFame(1)
    hof.update(population)

    # GA parameters
    CXPB, MUTPB = 0.7, 0.2 # Crossover and mutation probabilities
    NGEN = 1000 # Number of generations

    # Run the GA
    pop, logbook = algorithms.eaSimple(
        population,
        toolbox,
        cxpb=CXPB,
        mutpb=MUTPB,
        ngen=NGEN,
        halloffame=hof, # <--- Add this argument
        verbose=True
    )

    # Extract the best individual from final population
    best_individual = tools.selBest(pop, k=1)[0]
    best_params = np.array(best_individual)
    best_value = objective_function(best_params)
    fitness_pop = best_individual.fitness.values[0]

    # Extract the historical best from Hall of Fame
    if len(hof) == 0:
        print("Warning: Hall of Fame is empty!")
        best_params_historical = best_params
        best_value_historical = best_value
    else:
        best_historical = hof[0]
        best_params_historical = np.array(best_historical)
        best_value_historical = objective_function(best_params_historical)
        fitness_historical = best_historical.fitness.values[0]

    # Debugging fitness consistency
    print(f"\nDebugging Fitness Consistency:")
    print(f"Final Pop - Stored Fitness: {fitness_pop:.2e}, Computed: {best_value:.2e}")
    if len(hof) > 0:
        print(f"Historical - Stored Fitness: {fitness_historical:.2e}, Computed: {best_value_historical:.2e}")

    # Check if HoF is worse than final population
    if best_value_historical > best_value:
        print("Warning: Historical best is worse than final population best!")

    # Print results
    print("\nOptimization Results:")
    print("Best parameters from final population (d_i):")
    for i, d in enumerate(best_params):
        print(f"d_{i+1} = {d:.2e}")
    print(f"Minimum value of f (final population): {best_value:.2e}")

    print("\nHistorical Best Parameters (d_i):")
    for i, d in enumerate(best_params_historical):
        print(f"d_{i+1} = {d:.2e}")
    print(f"Minimum value of f (historical best): {best_value_historical:.2e}")

    return best_params, best_params_historical

if __name__ == "__main__":
    best_params, best_params_historical = GA_sim()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 import numpy as np
#       2 import random
# ----> 3 from deap import base, creator, tools, algorithms
#       5 # Define the objective function
#       6 def objective_function(d):
#
# ModuleNotFoundError: No module named 'deap'

# %%
# Wavelength sweep
wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
transmittances_hof = [calculate_transmittance(wl, best_params_historical, eps1, eps2) for wl in wavelengths]
transmittances = [calculate_transmittance(wl, best_params, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, 'b-')
plt.plot(wavelengths*1e9, transmittances_hof, 'b-.')
plt.plot(target_wl * 1e9, target_trans, 'r--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Wavelength sweep
#       2 wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
# ----> 3 transmittances_hof = [calculate_transmittance(wl, best_params_historical, eps1, eps2) for wl in wavelengths]
#       4 transmittances = [calculate_transmittance(wl, best_params, eps1, eps2) for wl in wavelengths]
#       6 # Plot
#
# Cell In[14], line 3, in <listcomp>(.0)
#       1 # Wavelength sweep
#       2 wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
# ----> 3 transmittances_hof = [calculate_transmittance(wl, best_params_historical, eps1, eps2) for wl in wavelengths]
#       4 transmittances = [calculate_transmittance(wl, best_params, eps1, eps2) for wl in wavelengths]
#       6 # Plot
#
# NameError: name 'best_params_historical' is not defined

# %%
from scipy.optimize import differential_evolution

# Define the objective function (example: sum of squares)
# Replace this with your actual function
def objective_function(d):
    return fom(d)  # Example: minimize sum of d_i^2

# Define bounds for the 10 parameters
bounds = [(0, 300e-9) for _ in range(10)]  # Each d_i between 0 and 300e-9

# Run Differential Evolution
result = differential_evolution(
    objective_function,    # Function to minimize
    bounds,                # Parameter bounds
    strategy='best1bin',   # DE strategy (can adjust: 'best1bin', 'rand1exp', etc.)
    maxiter=500,          # Maximum iterations
    popsize=30,            # Population size multiplier (15 * 10 = 150 individuals)
    tol=1e-9,              # Convergence tolerance
    mutation=(0.5, 1),     # Mutation factor range
    recombination=0.7,     # Crossover probability
 #  seed=42,               # Random seed for reproducibility
    disp=True              # Print progress
)

# Extract results
best_params = result.x
best_value = result.fun

# Print results
print("\nOptimization Results:")
print("Best parameters (d_i):")
for i, d in enumerate(best_params):
    print(f"d_{i+1} = {d:.2e}")
print(f"Minimum value of f: {best_value:.2e}")

# Optional: return results for further use
# return best_params, best_value
# Out:
# differential_evolution step 1: f(x)= 0.04758581941927346
# differential_evolution step 2: f(x)= 0.037075345985512445
# differential_evolution step 3: f(x)= 0.037075345985512445
# differential_evolution step 4: f(x)= 0.037075345985512445
# differential_evolution step 5: f(x)= 0.037075345985512445
# differential_evolution step 6: f(x)= 0.037075345985512445
# differential_evolution step 7: f(x)= 0.027876204752594398
# differential_evolution step 8: f(x)= 0.027876204752594398
# differential_evolution step 9: f(x)= 0.027876204752594398
# differential_evolution step 10: f(x)= 0.027876204752594398
# differential_evolution step 11: f(x)= 0.027876204752594398
# differential_evolution step 12: f(x)= 0.027876204752594398
# differential_evolution step 13: f(x)= 0.027876204752594398
# differential_evolution step 14: f(x)= 0.027876204752594398
# differential_evolution step 15: f(x)= 0.027876204752594398
# differential_evolution step 16: f(x)= 0.027876204752594398
# differential_evolution step 17: f(x)= 0.027876204752594398
# differential_evolution step 18: f(x)= 0.027876204752594398
# differential_evolution step 19: f(x)= 0.027876204752594398
# differential_evolution step 20: f(x)= 0.027876204752594398
# differential_evolution step 21: f(x)= 0.027876204752594398
# differential_evolution step 22: f(x)= 0.027876204752594398
# differential_evolution step 23: f(x)= 0.027876204752594398
# differential_evolution step 24: f(x)= 0.027876204752594398
# differential_evolution step 25: f(x)= 0.027876204752594398
# differential_evolution step 26: f(x)= 0.027876204752594398
# differential_evolution step 27: f(x)= 0.0179887608277201
# differential_evolution step 28: f(x)= 0.0179887608277201
# differential_evolution step 29: f(x)= 0.0179887608277201
# differential_evolution step 30: f(x)= 0.0179887608277201
# differential_evolution step 31: f(x)= 0.0179887608277201
# differential_evolution step 32: f(x)= 0.0179887608277201
# differential_evolution step 33: f(x)= 0.0179887608277201
# differential_evolution step 34: f(x)= 0.0179887608277201
# differential_evolution step 35: f(x)= 0.0179887608277201
# differential_evolution step 36: f(x)= 0.0179887608277201
# differential_evolution step 37: f(x)= 0.0179887608277201
# differential_evolution step 38: f(x)= 0.0179887608277201
# differential_evolution step 39: f(x)= 0.0179887608277201
# differential_evolution step 40: f(x)= 0.0179887608277201
# differential_evolution step 41: f(x)= 0.0179887608277201
# differential_evolution step 42: f(x)= 0.0179887608277201
# differential_evolution step 43: f(x)= 0.0179887608277201
# differential_evolution step 44: f(x)= 0.0179887608277201
# differential_evolution step 45: f(x)= 0.0179887608277201
# differential_evolution step 46: f(x)= 0.009805207358103777
# differential_evolution step 47: f(x)= 0.009805207358103777
# differential_evolution step 48: f(x)= 0.009805207358103777
# differential_evolution step 49: f(x)= 0.009805207358103777
# differential_evolution step 50: f(x)= 0.009805207358103777
# differential_evolution step 51: f(x)= 0.009805207358103777
# differential_evolution step 52: f(x)= 0.009805207358103777
# differential_evolution step 53: f(x)= 0.009805207358103777
# differential_evolution step 54: f(x)= 0.009805207358103777
# differential_evolution step 55: f(x)= 0.009805207358103777
# differential_evolution step 56: f(x)= 0.009805207358103777
# differential_evolution step 57: f(x)= 0.009805207358103777
# differential_evolution step 58: f(x)= 0.009805207358103777
# differential_evolution step 59: f(x)= 0.009805207358103777
# differential_evolution step 60: f(x)= 0.009805207358103777
# differential_evolution step 61: f(x)= 0.009805207358103777
# differential_evolution step 62: f(x)= 0.009805207358103777
# differential_evolution step 63: f(x)= 0.009805207358103777
# differential_evolution step 64: f(x)= 0.009805207358103777
# differential_evolution step 65: f(x)= 0.009805207358103777
# differential_evolution step 66: f(x)= 0.009805207358103777
# differential_evolution step 67: f(x)= 0.009805207358103777
# differential_evolution step 68: f(x)= 0.009805207358103777
# differential_evolution step 69: f(x)= 0.009805207358103777
# differential_evolution step 70: f(x)= 0.009805207358103777
# differential_evolution step 71: f(x)= 0.009805207358103777
# differential_evolution step 72: f(x)= 0.009805207358103777
# differential_evolution step 73: f(x)= 0.009805207358103777
# differential_evolution step 74: f(x)= 0.009805207358103777
# differential_evolution step 75: f(x)= 0.009805207358103777
# differential_evolution step 76: f(x)= 0.009265741095760257
# differential_evolution step 77: f(x)= 0.009265741095760257
# differential_evolution step 78: f(x)= 0.009265741095760257
# differential_evolution step 79: f(x)= 0.009265741095760257
# differential_evolution step 80: f(x)= 0.009265741095760257
# differential_evolution step 81: f(x)= 0.009265741095760257
# differential_evolution step 82: f(x)= 0.009265741095760257
# differential_evolution step 83: f(x)= 0.009265741095760257
# differential_evolution step 84: f(x)= 0.009265741095760257
# differential_evolution step 85: f(x)= 0.009265741095760257
# differential_evolution step 86: f(x)= 0.009265741095760257
# differential_evolution step 87: f(x)= 0.009265741095760257
# differential_evolution step 88: f(x)= 0.009265741095760257
# differential_evolution step 89: f(x)= 0.009265741095760257
# differential_evolution step 90: f(x)= 0.009265741095760257
# differential_evolution step 91: f(x)= 0.009265741095760257
# differential_evolution step 92: f(x)= 0.009265741095760257
# differential_evolution step 93: f(x)= 0.009265741095760257
# differential_evolution step 94: f(x)= 0.009265741095760257
# differential_evolution step 95: f(x)= 0.009265741095760257
# differential_evolution step 96: f(x)= 0.009265741095760257
# differential_evolution step 97: f(x)= 0.009265741095760257
# differential_evolution step 98: f(x)= 0.009265741095760257
# differential_evolution step 99: f(x)= 0.009265741095760257
# differential_evolution step 100: f(x)= 0.009265741095760257
# differential_evolution step 101: f(x)= 0.009265741095760257
# differential_evolution step 102: f(x)= 0.009265741095760257
# differential_evolution step 103: f(x)= 0.009265741095760257
# differential_evolution step 104: f(x)= 0.009265741095760257
# differential_evolution step 105: f(x)= 0.009265741095760257
# differential_evolution step 106: f(x)= 0.009265741095760257
# differential_evolution step 107: f(x)= 0.009265741095760257
# differential_evolution step 108: f(x)= 0.009265741095760257
# differential_evolution step 109: f(x)= 0.009265741095760257
# differential_evolution step 110: f(x)= 0.009265741095760257
# differential_evolution step 111: f(x)= 0.009265741095760257
# differential_evolution step 112: f(x)= 0.009265741095760257
# differential_evolution step 113: f(x)= 0.009265741095760257
# differential_evolution step 114: f(x)= 0.009265741095760257
# differential_evolution step 115: f(x)= 0.009265741095760257
# differential_evolution step 116: f(x)= 0.008489512058188665
# differential_evolution step 117: f(x)= 0.008489512058188665
# differential_evolution step 118: f(x)= 0.008489512058188665
# differential_evolution step 119: f(x)= 0.008489512058188665
# differential_evolution step 120: f(x)= 0.008489512058188665
# differential_evolution step 121: f(x)= 0.008489512058188665
# differential_evolution step 122: f(x)= 0.008489512058188665
# differential_evolution step 123: f(x)= 0.008489512058188665
# differential_evolution step 124: f(x)= 0.008489512058188665
# differential_evolution step 125: f(x)= 0.008489512058188665
# differential_evolution step 126: f(x)= 0.008489512058188665
# differential_evolution step 127: f(x)= 0.008489512058188665
# differential_evolution step 128: f(x)= 0.008489512058188665
# differential_evolution step 129: f(x)= 0.008489512058188665
# differential_evolution step 130: f(x)= 0.008489512058188665
# differential_evolution step 131: f(x)= 0.008489512058188665
# differential_evolution step 132: f(x)= 0.008489512058188665
# differential_evolution step 133: f(x)= 0.008489512058188665
# differential_evolution step 134: f(x)= 0.008489512058188665
# differential_evolution step 135: f(x)= 0.008489512058188665
# differential_evolution step 136: f(x)= 0.008489512058188665
# differential_evolution step 137: f(x)= 0.008489512058188665
# differential_evolution step 138: f(x)= 0.008489512058188665
# differential_evolution step 139: f(x)= 0.008489512058188665
# differential_evolution step 140: f(x)= 0.008489512058188665

# %%
# Wavelength sweep
wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
transmittances = [calculate_transmittance(wl, best_params, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, '-')
plt.plot(target_wl * 1e9, target_trans, 'r--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()

# %%
# Zebra Optimization Algorithm
# pip install --upgrade mealpy
import numpy as np
from mealpy.swarm_based import ZOA
from mealpy import FloatVar

# Define your objective function
def objective_function(solution):
    return fom(solution)

# Define the problem
problem = {
    "bounds": FloatVar(lb=([0]*10) , ub=([300e-9]*10) , name="delta"),
    "minmax": "min",
    "obj_func": objective_function,
    "verbose": False
}

# Initialize the ZOA model
model = ZOA.OriginalZOA(epoch=100, pop_size=500)

# Solve the optimization problem
best_agent = model.solve(problem)
best_solution = best_agent.solution
best_fitness = best_agent.target.fitness


print(f"Best Solution: {best_solution}")
print(f"Best Fitness: {best_fitness}")
# Out:
# 2025/04/15 05:51:02 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: Solving single objective optimization problem.
# 2025/04/15 05:51:04 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 1, Current best: 0.03799626074130216, Global best: 0.03799626074130216, Runtime: 1.85283 seconds
# 2025/04/15 05:51:06 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 2, Current best: 0.03799626074130216, Global best: 0.03799626074130216, Runtime: 1.91705 seconds
# 2025/04/15 05:51:08 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 3, Current best: 0.03799626074130216, Global best: 0.03799626074130216, Runtime: 1.84414 seconds
# 2025/04/15 05:51:10 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 4, Current best: 0.03799626074130216, Global best: 0.03799626074130216, Runtime: 1.84412 seconds
# 2025/04/15 05:51:12 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 5, Current best: 0.03799626074130216, Global best: 0.03799626074130216, Runtime: 1.84253 seconds
# 2025/04/15 05:51:14 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 6, Current best: 0.03799626074130216, Global best: 0.03799626074130216, Runtime: 1.84791 seconds
# 2025/04/15 05:51:16 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 7, Current best: 0.03387952052240879, Global best: 0.03387952052240879, Runtime: 1.84500 seconds
# 2025/04/15 05:51:17 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 8, Current best: 0.03387952052240879, Global best: 0.03387952052240879, Runtime: 1.84881 seconds
# 2025/04/15 05:51:19 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 9, Current best: 0.02992843030253179, Global best: 0.02992843030253179, Runtime: 1.84969 seconds
# 2025/04/15 05:51:21 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 10, Current best: 0.02992843030253179, Global best: 0.02992843030253179, Runtime: 1.85205 seconds
# 2025/04/15 05:51:23 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 11, Current best: 0.02992843030253179, Global best: 0.02992843030253179, Runtime: 1.85255 seconds
# 2025/04/15 05:51:25 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 12, Current best: 0.02992843030253179, Global best: 0.02992843030253179, Runtime: 1.85705 seconds
# 2025/04/15 05:51:27 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 13, Current best: 0.029669736165073058, Global best: 0.029669736165073058, Runtime: 1.85774 seconds
# 2025/04/15 05:51:29 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 14, Current best: 0.029149332425106807, Global best: 0.029149332425106807, Runtime: 1.84706 seconds
# 2025/04/15 05:51:30 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 15, Current best: 0.029149332425106807, Global best: 0.029149332425106807, Runtime: 1.84838 seconds
# 2025/04/15 05:51:32 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 16, Current best: 0.029149332425106807, Global best: 0.029149332425106807, Runtime: 1.84517 seconds
# 2025/04/15 05:51:34 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 17, Current best: 0.027291784904142725, Global best: 0.027291784904142725, Runtime: 1.91366 seconds
# 2025/04/15 05:51:36 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 18, Current best: 0.027002227101209735, Global best: 0.027002227101209735, Runtime: 1.84804 seconds
# 2025/04/15 05:51:38 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 19, Current best: 0.027002227101209735, Global best: 0.027002227101209735, Runtime: 1.84951 seconds
# 2025/04/15 05:51:40 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 20, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.84471 seconds
# 2025/04/15 05:51:42 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 21, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.84832 seconds
# 2025/04/15 05:51:43 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 22, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.85275 seconds
# 2025/04/15 05:51:45 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 23, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.85470 seconds
# 2025/04/15 05:51:47 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 24, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.85971 seconds
# 2025/04/15 05:51:49 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 25, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.85443 seconds
# 2025/04/15 05:51:51 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 26, Current best: 0.026832089681463805, Global best: 0.026832089681463805, Runtime: 1.85459 seconds
# 2025/04/15 05:51:53 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 27, Current best: 0.026585863516981095, Global best: 0.026585863516981095, Runtime: 1.85397 seconds
# 2025/04/15 05:51:55 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 28, Current best: 0.026585863516981095, Global best: 0.026585863516981095, Runtime: 1.85416 seconds
# 2025/04/15 05:51:56 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 29, Current best: 0.026585863516981095, Global best: 0.026585863516981095, Runtime: 1.85288 seconds
# 2025/04/15 05:51:58 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 30, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.85609 seconds
# 2025/04/15 05:52:00 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 31, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84338 seconds
# 2025/04/15 05:52:02 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 32, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.83752 seconds
# 2025/04/15 05:52:04 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 33, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.83571 seconds
# 2025/04/15 05:52:06 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 34, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.89634 seconds
# 2025/04/15 05:52:08 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 35, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84289 seconds
# 2025/04/15 05:52:09 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 36, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84449 seconds
# 2025/04/15 05:52:11 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 37, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84417 seconds
# 2025/04/15 05:52:13 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 38, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84294 seconds
# 2025/04/15 05:52:15 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 39, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84344 seconds
# 2025/04/15 05:52:17 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 40, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84271 seconds
# 2025/04/15 05:52:19 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 41, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84791 seconds
# 2025/04/15 05:52:21 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 42, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84591 seconds
# 2025/04/15 05:52:22 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 43, Current best: 0.023016349178452196, Global best: 0.023016349178452196, Runtime: 1.84395 seconds
# 2025/04/15 05:52:24 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 44, Current best: 0.020110495082664052, Global best: 0.020110495082664052, Runtime: 1.84386 seconds
# 2025/04/15 05:52:26 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 45, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.84991 seconds
# 2025/04/15 05:52:28 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 46, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.85310 seconds
# 2025/04/15 05:52:30 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 47, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.84573 seconds
# 2025/04/15 05:52:32 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 48, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.84386 seconds
# 2025/04/15 05:52:33 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 49, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.84391 seconds
# 2025/04/15 05:52:35 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 50, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.83542 seconds
# 2025/04/15 05:52:37 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 51, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 2.04878 seconds
# 2025/04/15 05:52:39 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 52, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.84385 seconds
# 2025/04/15 05:52:41 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 53, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.83277 seconds
# 2025/04/15 05:52:43 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 54, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.85166 seconds
# 2025/04/15 05:52:45 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 55, Current best: 0.017397662981109115, Global best: 0.017397662981109115, Runtime: 1.84514 seconds
# 2025/04/15 05:52:47 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 56, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84621 seconds
# 2025/04/15 05:52:48 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 57, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.85113 seconds
# 2025/04/15 05:52:50 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 58, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84522 seconds
# 2025/04/15 05:52:52 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 59, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84360 seconds
# 2025/04/15 05:52:54 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 60, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84547 seconds
# 2025/04/15 05:52:56 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 61, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.85312 seconds
# 2025/04/15 05:52:58 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 62, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.93949 seconds
# 2025/04/15 05:53:00 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 63, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.86085 seconds
# 2025/04/15 05:53:01 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 64, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.85558 seconds
# 2025/04/15 05:53:03 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 65, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.83531 seconds
# 2025/04/15 05:53:05 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 66, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.83816 seconds
# 2025/04/15 05:53:07 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 67, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84308 seconds
# 2025/04/15 05:53:09 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 68, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.90928 seconds
# 2025/04/15 05:53:11 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 69, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84397 seconds
# 2025/04/15 05:53:13 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 70, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84429 seconds
# 2025/04/15 05:53:14 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 71, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.84472 seconds
# 2025/04/15 05:53:16 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 72, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.95373 seconds
# 2025/04/15 05:53:19 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 73, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.34349 seconds
# 2025/04/15 05:53:21 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 74, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.29610 seconds
# 2025/04/15 05:53:23 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 75, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.33330 seconds
# 2025/04/15 05:53:26 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 76, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.14933 seconds
# 2025/04/15 05:53:28 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 77, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.34045 seconds
# 2025/04/15 05:53:30 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 78, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 1.95503 seconds
# 2025/04/15 05:53:32 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 79, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.17464 seconds
# 2025/04/15 05:53:34 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 80, Current best: 0.016818292144279677, Global best: 0.016818292144279677, Runtime: 2.47599 seconds
# 2025/04/15 05:53:37 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 81, Current best: 0.016812828917862403, Global best: 0.016812828917862403, Runtime: 2.23343 seconds
# 2025/04/15 05:53:39 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 82, Current best: 0.016812651285131493, Global best: 0.016812651285131493, Runtime: 2.60047 seconds
# 2025/04/15 05:53:42 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 83, Current best: 0.016812651285131493, Global best: 0.016812651285131493, Runtime: 2.42236 seconds
# 2025/04/15 05:53:44 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 84, Current best: 0.016812558263324267, Global best: 0.016812558263324267, Runtime: 2.28315 seconds
# 2025/04/15 05:53:47 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 85, Current best: 0.016812558263324267, Global best: 0.016812558263324267, Runtime: 2.69544 seconds
# 2025/04/15 05:53:49 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 86, Current best: 0.01668839796258226, Global best: 0.01668839796258226, Runtime: 2.37020 seconds
# 2025/04/15 05:53:51 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 87, Current best: 0.01668839796258226, Global best: 0.01668839796258226, Runtime: 2.33748 seconds
# 2025/04/15 05:53:54 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 88, Current best: 0.01665911867506403, Global best: 0.01665911867506403, Runtime: 2.36362 seconds
# 2025/04/15 05:53:56 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 89, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.30046 seconds
# 2025/04/15 05:53:59 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 90, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.53960 seconds
# 2025/04/15 05:54:01 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 91, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.50257 seconds
# 2025/04/15 05:54:04 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 92, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.39378 seconds
# 2025/04/15 05:54:06 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 93, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.60052 seconds
# 2025/04/15 05:54:08 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 94, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.23975 seconds
# 2025/04/15 05:54:11 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 95, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.60917 seconds
# 2025/04/15 05:54:13 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 96, Current best: 0.016538862708900464, Global best: 0.016538862708900464, Runtime: 2.35720 seconds
# 2025/04/15 05:54:16 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 97, Current best: 0.016499299923961083, Global best: 0.016499299923961083, Runtime: 2.52262 seconds
# 2025/04/15 05:54:18 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 98, Current best: 0.016499299923961083, Global best: 0.016499299923961083, Runtime: 2.43923 seconds
# 2025/04/15 05:54:21 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 99, Current best: 0.016456103157561092, Global best: 0.016456103157561092, Runtime: 2.35346 seconds
# 2025/04/15 05:54:23 AM, INFO, mealpy.swarm_based.ZOA.OriginalZOA: >>>Problem: P, Epoch: 100, Current best: 0.016456103157561092, Global best: 0.016456103157561092, Runtime: 2.67858 seconds
# Best Solution: [1.43760136e-07 2.25819010e-07 1.36553346e-07 1.03409393e-07
#  1.23477516e-07 1.86394883e-07 2.21696406e-07 7.74228165e-08
#  4.85482573e-08 1.01222654e-07]
# Best Fitness: 0.016456103157561092

# %%
# Wavelength sweep
wavelengths = np.linspace(600e-9, 700e-9, 21)  # 300-800 nm
transmittances = [calculate_transmittance(wl, best_solution, eps1, eps2) for wl in wavelengths]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(wavelengths*1e9, transmittances, '-')
plt.plot(target_wl * 1e9, target_trans, 'r--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')
plt.ylim([0,1.05])
plt.title('Transmittance vs Wavelength')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Use Python script for a long computation
# `ipynb` or Jupyter Notebook is a good environment for initializing code and playing with it.
# But, it is not ideal if you want to run a long simulation and leave for lunch. In this case,
# you run the code in the terminal with `nohup`
#
# ```
# nohup python 04_OTID_trans_TMM_zoa.py > zoa.out &
# ```
#
# I wrote a Python file `04_OTID_trans_TMM_zoa.py` to wrap the transmission calculation as a function by writing
# ``` python
# def calculate_transmittance(wavelength, thicknesses, epsilon_1, epsilon_2):
# ```
# In `04_OTID_trans_TMM_zoa.py`, I also wrote the optimization
#
# ``` python
# # Zebra Optimization Algorithm
# # pip install --upgrade mealpy
# from mealpy.swarm_based import ZOA
# from mealpy import FloatVar
#
# # Define your objective function
# def objective_function(solution):
#     return fom(solution)
#
# # Define the problem
# problem = {
#     "bounds": FloatVar(lb=([0]*10) , ub=([300e-9]*10) , name="delta"),
#     "minmax": "min",
#     "obj_func": objective_function,
#     "verbose": False
# }
#
# # Initialize the ZOA model
# model = ZOA.OriginalZOA(epoch=100, pop_size=100)
#
# # Solve the optimization problem
# best_agent = model.solve(problem)
# best_solution = best_agent.solution
# best_fitness = best_agent.target.fitness
#
#
# print(f"Best Solution: {best_solution}")
# print(f"Best Fitness: {best_fitness}")
#
# ```
#
# - First, run the code with the command
# ```
# nohup python 04_OTID_trans_TMM_zoa.py > zoa.out &
# ```
# - See the result files.
# - Write your own file by replacing the optimization method.
