# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
## import my colormap
import mycmapls as ms
mycmap = ms.mycmap
mycmap1 = ms.mycmap1
mycmap2 = ms.mycmap2

# %%
Nx = 100
Ny = 100
pot = np.zeros((Nx,Ny))

# %%
pot[:,5] = 1

# %%
plt.figure(dpi=150)
plt.pcolormesh(pot,alpha= 0.8,cmap="jet")
plt.colorbar()
plt.show()

# %%
for ix in range(1,Nx-1):
    for iy in range(1,Ny-1):
        pot[ix,iy] = 1/4 * (pot[ix,iy+1] + pot[ix+1,iy] + pot[ix-1,iy] + pot[ix-1,iy])
# Out:
# 0
# 1
# 2
# 3
# 4
