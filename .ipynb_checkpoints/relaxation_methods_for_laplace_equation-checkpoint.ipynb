# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
## import my colormap
import mycmapls as ms
mycmap = ms.mycmap
mycmap1 = ms.mycmap1
mycmap2 = ms.mycmap2

# %%
Nx = 100
Ny = 100
pot = np.zeros((Nx,Ny))

# %%
## BCs
def appl_BCs(pot_in):
    pot_out = pot_in
    pot_out[0,0:Ny-1] = 1
    pot_out[Nx-1,0:Ny] = 0
    pot_out[0:Nx-1,0] = 0
    pot_out[0:Nx-1,Ny-1] = 0

    pot_out[int(Nx/4),int(Ny/4):int(Ny/4*3)] = 0
    pot_out[int(Nx/4*3),int(Ny/4):int(Ny/4*3)+1] = 0
    pot_out[int(Nx/4):int(Nx/4*3),int(Ny/4)] = 0
    pot_out[int(Nx/4):int(Nx/4*3),int(Ny/4*3)] = 0
    
    return pot_out

pot =  appl_BCs(pot)

# %%
plt.figure(dpi=150)
plt.pcolormesh(pot.transpose(),alpha= 0.8,cmap=mycmap)
plt.colorbar()
plt.show()

# %%
Nt = 100 # num of iteration 
for it in range(Nt):
    for ix in range(1,Nx-1):
        for iy in range(1,Ny-1):
            pot = appl_BCs(pot)
            pot[ix,iy] = 1/4 * (pot[ix,iy+1] + pot[ix+1,iy] + pot[ix-1,iy] + pot[ix,iy-1])

# %%
plt.figure(dpi=150)
plt.pcolormesh(pot.transpose(),alpha= 0.8,cmap="jet")
plt.colorbar()
plt.show()

# %%
np.max(np.abs(tmp - pot))
# Out:
# 2.0
