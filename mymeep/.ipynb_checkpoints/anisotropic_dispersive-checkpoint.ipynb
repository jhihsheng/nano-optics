# %% [markdown]
# - $\epsilon_\infty$: a constant
#
# We can set the anisotropic and dispersive epsilon by using **`epsilon_diag`** in `mp.Medium`.
#
# - $\omega_n$: resonant frequency
# - $\gamma_n$: damping rate
# - $\sigma_n$: scale factor of the $n$ resonator
#
# We can set the anisotropic and dispersive epsilon by using **`sigma_diag`** in `mp.LorentzianSusceptibility`.
#
# $$\epsilon = \epsilon_\infty + \sum_n \frac{\sigma_n f_n^2}{f_n^2 - f(f+i\gamma)}$$
#
# Note:  there is no need to divide $\gamma$ by $2\pi$. The definition in the example of [Meep doc](https://meep.readthedocs.io/en/latest/Python_Tutorials/Material_Dispersion/) seems wrong.

# %% [markdown]
# hBN10
# $$\epsilon_\infty = \begin{pmatrix} 5.1 & 0 & 0 \\ 0 & 5.1 & 0 \\ 0 & 0 & 2.5 \end{pmatrix}$$
# The oscillator in the ordinary dirction
# - $f_o = 1394.5$ cm$^{-1}$ = 0.13945  $\mu$m$^{-1}$
# - $\gamma_o=$1.8  cm$^{-1}$ = 0.00018  $\mu$m$^{-1}$
# - $\sigma_o = 2.04$
#
# The oscillator in the extraordinary dirction
# - $f_e = 785 $ cm$^{-1}$ = 0.0785  $\mu$m$^{-1}$
# - $\gamma_e=$1 cm$^{-1}$ = 0.0001  $\mu$m$^{-1}$
# - $\sigma_e = 0.3068$

# %%
import numpy as np
import meep as mp
from matplotlib import pyplot as plt
## import my colormap
import mycmapls as ms
mycmap = ms.mycmap
mycmap1 = ms.mycmap1
mycmap2 = ms.mycmap2
bicmap = ms.bicmap

### hBN10

hBN10_fo = 0.13945
hBN10_gammao = 0.00018
hBN10_sigo = 2.04

hBN10_susc_o = [
    mp.LorentzianSusceptibility(
        frequency=hBN10_fo,
        gamma=hBN10_gammao,
        sigma_diag=hBN10_sigo * mp.Vector3(1, 1, 0)
    )
]
   

hBN10_fe = 0.0785
hBN10_gammae =  0.0001
hBN10_sige = 0.3068

hBN10_susc_e = [
    mp.LorentzianSusceptibility(
        frequency=hBN10_fe,
        gamma=hBN10_gammae,
        sigma_diag=hBN10_sige * mp.Vector3(0, 0, 1)
    )
]
  

hBN10 = mp.Medium(
    epsilon_diag=mp.Vector3(5.1, 5.1, 2.5),
    E_susceptibilities= hBN10_susc_o + hBN10_susc_e,
    
)

### hBN11

hBN11_fo = 0.13598
hBN11_gammao = 0.00021
hBN11_sigo = 2.1258

hBN11_susc_o = [
    mp.LorentzianSusceptibility(
        frequency=hBN11_fo,
        gamma=hBN11_gammao,
        sigma_diag=hBN11_sigo * mp.Vector3(1, 1, 0)
    )
]
   

hBN11_fe = 0.0755
hBN11_gammae =  0.0001
hBN11_sige = 0.5116

hBN11_susc_e = [
    mp.LorentzianSusceptibility(
        frequency=hBN11_fe,
        gamma=hBN11_gammae,
        sigma_diag=hBN11_sige * mp.Vector3(0, 0, 1)
    )
]
  

hBN11 = mp.Medium(
    epsilon_diag=mp.Vector3(5.32, 5.32, 3.15),
    E_susceptibilities= hBN11_susc_o + hBN11_susc_e,
    
)

# %%
Nf = 1000
fv = np.linspace(0.1350,0.1450,Nf)
eo = np.empty(Nf,dtype=complex)
eo_ana = 5.1 + hBN10_sigo * hBN10_fo**2 /(hBN10_fo**2 - fv**2 - 1j * fv * 0.00018)
eo_11 = np.empty(Nf,dtype=complex)

for i in range(Nf):
    eo[i] = hBN10.epsilon(fv[i])[0,0]
    eo_11[i] = hBN11.epsilon(fv[i])[0,0]
##
plt.figure(dpi=150)
plt.plot(fv * 10000,np.real(eo))
plt.plot(fv * 10000,np.real(eo_11))
plt.plot(fv * 10000,np.imag(eo),linewidth = 1,color = 'k')
plt.plot(fv * 10000,np.imag(eo_11),linewidth = 1,color = 'k')

plt.plot(fv * 10000,np.real(eo_ana),'--')
plt.xlim(1350,1450)
plt.grid()
plt.show()

# %%
cell = mp.Vector3(0.5,0.25)
geometry = [ mp.Block(mp.Vector3(mp.inf,0.050,mp.inf),
                     center = mp.Vector3(),
                    material = hBN11)
           ]

sources = [mp.Source(mp.ContinuousSource(frequency = 0.1420),
                     component=mp.Ey,
                    center=mp.Vector3(0,0.0),
                    size=mp.Vector3(0,0))
          ]
boundary_layers=[mp.Absorber(thickness=0.001)]
resolution = 500
sim = mp.Simulation(cell_size=cell,
                    boundary_layers=boundary_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.figure(dpi=100)
sim.plot2D()
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.19209e-05 s
# Working in 2D dimensions.
# Computational cell is 0.5 x 0.25 x 0 with resolution 500
#      block, center = (0,0,0)
#           size (1e+20,0.05,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.32,5.32,3.15)
# time for set_epsilon = 0.038599 s
# time for set_conductivity = 0.000999928 s
# time for set_conductivity = 0.000984907 s
# time for set_conductivity = 0.000994921 s
# time for set_conductivity = 0.001019 s
# time for set_conductivity = 0.00100684 s
# time for set_conductivity = 0.00101614 s
# lorentzian susceptibility: frequency=0.0755, gamma=0.0001
# lorentzian susceptibility: frequency=0.13598, gamma=0.00021
# -----------

# %%
sim.run(until= 1005)
# Out:
# FloatProgress(value=525.0, description='0% done ', max=1530.0, min=525.0)
# on time step 525000 (time=525), 0.0111567 s/step
# Meep progress: 25.201000000000022/1530.0 = 1.6% done in 4.0s, 238.9s to go
# on time step 550233 (time=550.233), 0.000158528 s/step
# Meep progress: 50.139999999999986/1530.0 = 3.3% done in 8.0s, 236.1s to go
# on time step 575174 (time=575.174), 0.000160383 s/step
# Meep progress: 75.03899999999999/1530.0 = 4.9% done in 12.0s, 232.7s to go
# on time step 600077 (time=600.077), 0.000160624 s/step
# Meep progress: 100.33299999999997/1530.0 = 6.6% done in 16.0s, 228.0s to go
# on time step 625374 (time=625.374), 0.000158122 s/step
# Meep progress: 125.53399999999999/1530.0 = 8.2% done in 20.0s, 223.8s to go
# on time step 650574 (time=650.574), 0.000158732 s/step
# Meep progress: 150.57100000000003/1530.0 = 9.8% done in 24.0s, 219.9s to go
# on time step 675619 (time=675.619), 0.000159714 s/step
# Meep progress: 175.62700000000007/1530.0 = 11.5% done in 28.0s, 215.9s to go
# on time step 700675 (time=700.675), 0.000159648 s/step
# Meep progress: 200.83400000000006/1530.0 = 13.1% done in 32.0s, 211.8s to go
# on time step 725889 (time=725.889), 0.000158646 s/step
# Meep progress: 226.14300000000003/1530.0 = 14.8% done in 36.0s, 207.6s to go
# on time step 751200 (time=751.2), 0.000158034 s/step
# Meep progress: 251.34299999999996/1530.0 = 16.4% done in 40.0s, 203.5s to go
# on time step 776404 (time=776.404), 0.000158711 s/step
# Meep progress: 276.562/1530.0 = 18.1% done in 44.0s, 199.4s to go
# on time step 801626 (time=801.626), 0.000158594 s/step
# Meep progress: 301.83000000000004/1530.0 = 19.7% done in 48.0s, 195.3s to go
# on time step 826894 (time=826.894), 0.000158307 s/step
# Meep progress: 327.062/1530.0 = 21.4% done in 52.0s, 191.3s to go
# on time step 852131 (time=852.131), 0.000158504 s/step
# Meep progress: 352.269/1530.0 = 23.0% done in 56.0s, 187.2s to go
# on time step 877343 (time=877.343), 0.000158656 s/step
# Meep progress: 377.427/1530.0 = 24.7% done in 60.0s, 183.2s to go
# on time step 902501 (time=902.501), 0.000159 s/step
# Meep progress: 402.447/1530.0 = 26.3% done in 64.0s, 179.3s to go
# on time step 927525 (time=927.525), 0.000159848 s/step
# Meep progress: 427.692/1530.0 = 28.0% done in 68.0s, 175.3s to go
# on time step 952770 (time=952.77), 0.000158449 s/step
# Meep progress: 452.884/1530.0 = 29.6% done in 72.0s, 171.2s to go
# on time step 977968 (time=977.968), 0.000158745 s/step
# Meep progress: 478.033/1530.0 = 31.2% done in 76.0s, 167.3s to go
# on time step 1003119 (time=1003.12), 0.000159042 s/step
# Meep progress: 503.12699999999995/1530.0 = 32.9% done in 80.0s, 163.3s to go
# on time step 1028215 (time=1028.21), 0.00015939 s/step
# Meep progress: 528.231/1530.0 = 34.5% done in 84.0s, 159.3s to go
# on time step 1053322 (time=1053.32), 0.000159319 s/step
# Meep progress: 553.483/1530.0 = 36.2% done in 88.0s, 155.3s to go
# on time step 1078576 (time=1078.58), 0.000158396 s/step
# Meep progress: 578.538/1530.0 = 37.8% done in 92.0s, 151.3s to go
# on time step 1103633 (time=1103.63), 0.000159637 s/step
# Meep progress: 603.242/1530.0 = 39.4% done in 96.0s, 147.5s to go
# on time step 1128339 (time=1128.34), 0.000161906 s/step
# Meep progress: 627.8820000000001/1530.0 = 41.0% done in 100.0s, 143.7s to go
# on time step 1152982 (time=1152.98), 0.000162321 s/step
# Meep progress: 652.875/1530.0 = 42.7% done in 104.0s, 139.7s to go
# on time step 1177980 (time=1177.98), 0.000160017 s/step
# Meep progress: 677.9200000000001/1530.0 = 44.3% done in 108.0s, 135.7s to go
# on time step 1203026 (time=1203.03), 0.000159709 s/step
# Meep progress: 703.0250000000001/1530.0 = 45.9% done in 112.0s, 131.7s to go
# on time step 1228136 (time=1228.14), 0.000159301 s/step
# Meep progress: 727.921/1530.0 = 47.6% done in 116.0s, 127.8s to go
# on time step 1253033 (time=1253.03), 0.000160663 s/step
# Meep progress: 752.8689999999999/1530.0 = 49.2% done in 120.0s, 123.9s to go
# on time step 1277984 (time=1277.98), 0.000160316 s/step
# Meep progress: 777.8030000000001/1530.0 = 50.8% done in 124.0s, 119.9s to go
# on time step 1302922 (time=1302.92), 0.000160398 s/step
# Meep progress: 802.6680000000001/1530.0 = 52.5% done in 128.0s, 116.0s to go
# on time step 1327788 (time=1327.79), 0.000160864 s/step
# Meep progress: 827.6700000000001/1530.0 = 54.1% done in 132.0s, 112.0s to go
# on time step 1352792 (time=1352.79), 0.000159981 s/step
# Meep progress: 852.6220000000001/1530.0 = 55.7% done in 136.0s, 108.0s to go
# on time step 1377750 (time=1377.75), 0.000160276 s/step
# Meep progress: 877.328/1530.0 = 57.3% done in 140.0s, 104.2s to go
# on time step 1402459 (time=1402.46), 0.000161887 s/step
# Meep progress: 902.2719999999999/1530.0 = 59.0% done in 144.0s, 100.2s to go
# on time step 1427407 (time=1427.41), 0.000160336 s/step
# Meep progress: 927.21/1530.0 = 60.6% done in 148.0s, 96.2s to go
# on time step 1452347 (time=1452.35), 0.000160389 s/step
# Meep progress: 951.9180000000001/1530.0 = 62.2% done in 152.0s, 92.3s to go
# on time step 1477057 (time=1477.06), 0.000161879 s/step
# Meep progress: 976.846/1530.0 = 63.8% done in 156.0s, 88.3s to go
# on time step 1501989 (time=1501.99), 0.000160438 s/step
# Meep progress: 1001.75/1530.0 = 65.5% done in 160.0s, 84.4s to go
# on time step 1526894 (time=1526.89), 0.000160611 s/step
# run 5 finished at t = 1530.0 (1530000 timesteps)

# %%
#
Ey = sim.get_array(component=mp.Ey, vol=mp.Volume(center=mp.Vector3(0,0), size=mp.Vector3(0.5,0.25)))
##
nx = Ey.shape[0]
ny = Ey.shape[1]
xv = np.linspace(-.25,.25,nx)
yv = np.linspace(-0.125,0.125,ny)
xx, yy = np.meshgrid(xv, yv)
plt.figure(dpi=150)
plt.pcolormesh(xx,yy,np.abs(np.transpose(Ey)), cmap= 'hot',alpha= 0.8,shading='gouraud')
plt.colorbar()
sim.plot2D(source_parameters={'alpha':0,'color':'white','linewidth':0.5})
plt.gca().set_aspect('equal', adjustable='box')
plt.clim(0,10.5)
plt.show()
